# %% [markdown]
# <a href="https://colab.research.google.com/github/vladlesnyh/optimization/blob/main/2_%D0%94%D0%B8%D0%B0%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B0_%D0%93%D0%B0%D0%BD%D1%82%D0%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Установка SimPy

# %%
# %pip install -U simpy
# Out:
# Requirement already satisfied: simpy in /usr/local/lib/python3.12/dist-packages (4.1.1)

# %% [markdown]
# ## Первая модель
#
# SimPy — это Python фреймворк для процессо-ориентированной дискретно-событийной системы моделирования. Он был разработан для создания асинхронных сетей и мультиагентных систем, как с моделируемым, так и с реальным взаимодействием.

# %%
# Импортировать библиотеку simpy
import simpy

# %%
# Функция выполнения операций по заявке
def order(env):

    # Выполнение

    print(f'{env.now:2.0f}, Мониторинг прибытия груженных контейнеров.')
    yield env.timeout(10)

    print(f'{env.now:2.0f}, Добавление контейнеров в диспетчерский график')
    yield env.timeout(3)

    print(f'{env.now:2.0f}, Уведомление о прибытии контейнеров клиента')
    yield env.timeout(1)

# %%
# Иницилизация среды выполнения имитационной модели
env = simpy.Environment(initial_time=0)

# В среду выполнения помещаем процесс с заявкой
env.process(order(env))

# Запускаем моделирование на 100 минут
env.run(until=100)
# Out:
#  0, Мониторинг прибытия груженных контейнеров.
# 10, Добавление контейнеров в диспетчерский график
# 13, Уведомление о прибытии контейнеров клиента

# %% [markdown]
# ## Выполним три заявки

# %%
# Инициализация среды выпполнения имитационной модели
env = simpy.Environment(initial_time=0)

# В среду выполнения помещаем три процесса
p1 = env.process(order(env))
p2 = env.process(order(env))
p3 = env.process(order(env))

# Запускаме моделирование на 100 минут
env.run(until=100)
# Out:
#  0, Мониторинг прибытия груженных контейнеров.
#  0, Мониторинг прибытия груженных контейнеров.
#  0, Мониторинг прибытия груженных контейнеров.
# 10, Добавление контейнеров в диспетчерский график
# 10, Добавление контейнеров в диспетчерский график
# 10, Добавление контейнеров в диспетчерский график
# 13, Уведомление о прибытии контейнеров клиента
# 13, Уведомление о прибытии контейнеров клиента
# 13, Уведомление о прибытии контейнеров клиента

# %% [markdown]
# ## Доработаем заявку

# %%
def oper(env, order, oper, wait, dur):
    # Ждем запуска
    yield env.timeout(wait)
    # Выполнение
    put = env.now # Время помещения в очередь
    yield env.timeout(dur)
    print(f'{put:2.0f}, {env.now:2.0f}, {order}, {oper} - {dur}')

def order(env, order, wait):
    # Ждем запуска
    yield env.timeout(wait)
    # Выполняем операции
    yield env.process(oper(env, order, 'Мониторинг прибытия груженных контейнеров', 0, 10))
    yield env.process(oper(env, order, 'Добавление контейнеров в диспетчерский график', 0, 30))
    yield env.process(oper(env, order, 'Уведомление о прибытии контейнеров клиента', 0, 5))

# %%
# Иницилизация среды выпполнения имитационной модели
env = simpy.Environment(initial_time=0)

# В среду выполнения помещаем три процесса
p1 = env.process(order(env, "Заявка 1", 0))
p2 = env.process(order(env, "Заявка 2", 5))
p3 = env.process(order(env, "Заявка 3", 10))

# Запускаме моделирование на 1440 минут
env.run(until=1440)
# Out:
#  0, 10, Заявка 1, Мониторинг прибытия груженных контейнеров - 10
#  5, 15, Заявка 2, Мониторинг прибытия груженных контейнеров - 10
# 10, 20, Заявка 3, Мониторинг прибытия груженных контейнеров - 10
# 10, 40, Заявка 1, Добавление контейнеров в диспетчерский график - 30
# 15, 45, Заявка 2, Добавление контейнеров в диспетчерский график - 30
# 40, 45, Заявка 1, Уведомление о прибытии контейнеров клиента - 5
# 20, 50, Заявка 3, Добавление контейнеров в диспетчерский график - 30
# 45, 50, Заявка 2, Уведомление о прибытии контейнеров клиента - 5
# 50, 55, Заявка 3, Уведомление о прибытии контейнеров клиента - 5

# %% [markdown]
# ## Добавим ресурс

# %%
def oper(env, manager, order, oper, wait, dur):
    # Ждем запуска
    yield env.timeout(wait)
    # Выполнение
    put = env.now # Время помещения в очередь
    with manager.request() as req: # Запрос освобождения ресурса
        yield req              # Ждем освобождение ресурса
        beg = env.now          # Начало выполнения
        delay = beg - put      # Задержка
        yield env.timeout(dur) # Время выполнения
        end = env.now          # Завершение выполнения
        print(f'{put:2.0f}, {beg:2.0f}, {end:2.0f}, {delay}, {len(manager.queue)}, {order}, {oper} - {dur}')

def order(env, manager, order, wait):
    # Ждем запуска
    yield env.timeout(wait)
    # Выполняем операции
    yield env.process(oper(env, manager, order, 'Мониторинг прибытия груженных контейнеров', 0, 10))
    yield env.process(oper(env, manager, order, 'Добавление контейнеров в диспетчерский график', 0, 30))
    yield env.process(oper(env, manager, order, 'Уведомление о прибытии контейнеров клиента', 0, 5))

# %%
# Иницилизация среды выпполнения имитационной модели
env = simpy.Environment(initial_time=0)

# Создаем ресурс - менеджер
num_managers = 1 # число менеджеров (взимо заменяемых)
manager = simpy.PriorityResource(env, num_managers)

# В среду выполнения помещаем три процесса
p1 = env.process(order(env, manager, "Заявка 1", 0))
p2 = env.process(order(env, manager, "Заявка 2", 5))
p3 = env.process(order(env, manager, "Заявка 3", 10))

# Запускаме моделирование на 1440 минут
env.run(until=1440)
# Out:
#  0,  0, 10, 0, 1, Заявка 1, Мониторинг прибытия груженных контейнеров - 10
#  5, 10, 20, 5, 2, Заявка 2, Мониторинг прибытия груженных контейнеров - 10
# 10, 20, 30, 10, 2, Заявка 3, Мониторинг прибытия груженных контейнеров - 10
# 10, 30, 60, 20, 2, Заявка 1, Добавление контейнеров в диспетчерский график - 30
# 20, 60, 90, 40, 2, Заявка 2, Добавление контейнеров в диспетчерский график - 30
# 30, 90, 120, 60, 2, Заявка 3, Добавление контейнеров в диспетчерский график - 30
# 60, 120, 125, 60, 2, Заявка 1, Уведомление о прибытии контейнеров клиента - 5
# 90, 125, 130, 35, 1, Заявка 2, Уведомление о прибытии контейнеров клиента - 5
# 120, 130, 135, 10, 0, Заявка 3, Уведомление о прибытии контейнеров клиента - 5

# %% [markdown]
# ## Добавим логи

# %%
def oper(env, manager, order, oper, wait, dur):
    # Ждем запуска
    yield env.timeout(wait)
    # Выполнение
    put = env.now # Время помещения в очередь
    with manager.request() as req: # Запрос особождения ресурса
        yield req              # Ждем осовбождение ресурса
        beg = env.now          # Начало выполнения
        delay = beg - put      # Задержка
        yield env.timeout(dur) # Время выполнения
        end = env.now          # Завершение выполнения
        #print(f'{put:2.0f}, {beg:2.0f}, {end:2.0f}, {delay}, {len(manager.queue)}, {order}, {oper} - {dur}')
        # Логи выполнения
        data_log.append([put, beg, end, delay, len(manager.queue), order, oper])

def order(env, manager, order, wait):
    # Ждем запуска
    yield env.timeout(wait)
    # Выполняем операции
    yield env.process(oper(env, manager, order, '1. Мониторинг прибытия груженных контейнеров', 0, 10))
    yield env.process(oper(env, manager, order, '2. Добавление контейнеров в диспетчерский график', 0, 30))
    yield env.process(oper(env, manager, order, '3. Уведомление о прибытии контейнеров клиента', 0, 5))

# %%
# Инициализация среды выпполнения имитационной модели
env = simpy.Environment(initial_time=0)

# Создаем ресурс - менеджер
num_managers = 1 # число менеджеров (взимозаменяемых)
manager = simpy.PriorityResource(env, num_managers)

# В среду выполнения помещаем три процесса
p1 = env.process(order(env, manager, "Заявка 1", 0))
p2 = env.process(order(env, manager, "Заявка 2", 5))
p3 = env.process(order(env, manager, "Заявка 3", 10))

# Лог
data_log = []

# Запускаем моделирование на 1440 минут
env.run(until=1440)

# Печать лога
data_log
# Out:
# [[0, 0, 10, 0, 1, 'Заявка 1', '1. Мониторинг прибытия груженных контейнеров'],
#  [5, 10, 20, 5, 2, 'Заявка 2', '1. Мониторинг прибытия груженных контейнеров'],
#  [10,
#   20,
#   30,
#   10,
#   2,
#   'Заявка 3',
#   '1. Мониторинг прибытия груженных контейнеров'],
#  [10,
#   30,
#   60,
#   20,
#   2,
#   'Заявка 1',
#   '2. Добавление контейнеров в диспетчерский график'],
#  [20,
#   60,
#   90,
#   40,
#   2,
#   'Заявка 2',
#   '2. Добавление контейнеров в диспетчерский график'],
#  [30,
#   90,
#   120,
#   60,
#   2,
#   'Заявка 3',
#   '2. Добавление контейнеров в диспетчерский график'],
#  [60,
#   120,
#   125,
#   60,
#   2,
#   'Заявка 1',
#   '3. Уведомление о прибытии контейнеров клиента'],
#  [90,
#   125,
#   130,
#   35,
#   1,
#   'Заявка 2',
#   '3. Уведомление о прибытии контейнеров клиента'],
#  [120,
#   130,
#   135,
#   10,
#   0,
#   'Заявка 3',
#   '3. Уведомление о прибытии контейнеров клиента']]

# %% [markdown]
# ## Научимся читать логи

# %% [markdown]
# Для это используем билиотеку pandas

# %%
import pandas as pd # библиотека для работы с данными
pd.DataFrame(data_log, columns=["put", "beg", "end", "delay", "queue", "order", "oper"])
# Out:
#    put  beg  end  delay  queue     order  \
# 0    0    0   10      0      1  Заявка 1
# 1    5   10   20      5      2  Заявка 2
# 2   10   20   30     10      2  Заявка 3
# 3   10   30   60     20      2  Заявка 1
# 4   20   60   90     40      2  Заявка 2
# 5   30   90  120     60      2  Заявка 3
# 6   60  120  125     60      2  Заявка 1
# 7   90  125  130     35      1  Заявка 2
# 8  120  130  135     10      0  Заявка 3
#
#                                                oper
# 0      1. Мониторинг прибытия груженных контейнеров
# 1      1. Мониторинг прибытия груженных контейнеров
# 2      1. Мониторинг прибытия груженных контейнеров
# 3  2. Добавление контейнеров в диспетчерский график
# 4  2. Добавление контейнеров в диспетчерский график
# 5  2. Добавление контейнеров в диспетчерский график
# 6     3. Уведомление о прибытии контейнеров клиента
# 7     3. Уведомление о прибытии контейнеров клиента
# 8     3. Уведомление о прибытии контейнеров клиента

# %% [markdown]
# ## Построим график в ручную

# %%
import matplotlib.pyplot as plt

# Создаим пустой график
fig, ax = plt.subplots(1, 1, figsize=(5, 3))

# Добавим на график линии
ax.plot([0,5], [0, 0], lw=20, alpha=0.9)
ax.plot([5,10], [1, 1], lw=20, alpha=0.9)
ax.plot([10,15], [2, 2], lw=20, alpha=0.9)

# Подпишем
ax.set_title("Диаграмма Ганта")
# Out:
# Text(0.5, 1.0, 'Диаграмма Ганта')

# %% [markdown]
# ## Построим график на основе данных

# %%
import numpy as np # линейная алгебра
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

def gant(df_data, lw=5, lh=3):

    # Добавлем колонки в data_log
    df_data = pd.DataFrame(data_log, columns=["put", "beg", "end", "delay", "queue", "order", "oper"])
    df_data["index"] = df_data[["order", "oper"]].apply(lambda x: ", ".join(x), axis=1)

    ## Составим список заявок, операций
    orders = sorted(list(set(df_data["order"])))
    opers = sorted(list(set(df_data["oper"])))

    # Перечислим цвета для операций
    colors = []
    for i in enumerate(opers):
        colors.append(f"C{i[0]}")

    # Добавим график
    fig, ax = plt.subplots(1, 1, figsize=(lw, lh))

    # График с заявками
    for j, order in enumerate(orders): # для каждой заявки
        for i, oper in enumerate(opers): # для каждого события
            # Нанесем на график начальную и конечную точки операции
            for k in df_data[(df_data["order"]==order) & (df_data["oper"]==oper)].index:
                    ax.plot([df_data["beg"][k], df_data["end"][k]], [j, j],
                             colors[i], solid_capstyle="butt", lw=20, alpha=0.9)


    lines = [Line2D([0], [0], lw=lw, color=colors[i]) for i in range(len(opers))]
    ax.legend(lines, opers, bbox_to_anchor=(1.05, 1.0), loc="upper left")

    ax.set_title("Диаграмма Ганта")
    ax.set_yticks(range(len(orders)))
    ax.set_yticklabels(orders)

gant(data_log)

# %% [markdown]
# ## Добавим время

# %%
import numpy as np # линейная алгебра
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from matplotlib.dates import HourLocator, DateFormatter
from matplotlib.lines import Line2D
from datetime import datetime

def gant(df_data, lw=8, lh=3):

    g = 0
    fig, ax = plt.subplots(1, 1, figsize=(lw, lh))

    # Добавлем колоноки в data_log
    df_data = pd.DataFrame(data_log, columns=["put", "beg", "end", "wait", "queue", "order", "oper"])

    # Добавим время
    df_data['t_put'] = pd.to_datetime((df_data['put']).astype('int'), unit='m')
    df_data['t_beg'] = pd.to_datetime((df_data['beg']).astype('int'), unit='m')
    df_data['t_end'] = pd.to_datetime((df_data['end']).astype('int'), unit='m')

    orders = sorted(list(set(df_data["order"])))
    opers = sorted(list(set(df_data["oper"])))

    colors = []
    for i in enumerate(opers):
        colors.append(f"C{i[0]}")

    lim_min = pd.to_datetime((df_data['beg'].min()), unit='m')
    lim_max = pd.to_datetime((df_data['beg'].max()), unit='m')

    # График с заявками
    for j, order in enumerate(orders): # для каждой заявки
        for i, oper in enumerate(opers): # для каждого события
            # Нанесем на график начальную и конечную точки
            for k in df_data[(df_data["order"]==order) & (df_data["oper"]==oper)].index:
                    ax.plot([df_data["t_beg"][k], df_data["t_end"][k]], [j, j],
                             colors[i], solid_capstyle="butt", lw=20, alpha=0.9)


    lines = [Line2D([0], [0], lw=lw, color=colors[i]) for i in range(len(opers))]
    ax.legend(lines, opers, bbox_to_anchor=(1.05, 1.0), loc="upper left")

    ax.set_title("Диаграмма Ганта")
    ax.set_yticks(range(len(orders)))
    ax.set_yticklabels(orders)

gant(data_log)

# %% [markdown]
# ## Пример со случайными величинами

# %%
import random

def oper(env, res, order, oper, wait, dur):
    # Ждем запуска
    yield env.timeout(wait)
    # Выполнение
    put = env.now # Время помещения в очередь
    with res.request() as req: # Запрос освобождения ресурса
        yield req              # Ждем освобождение ресурса
        beg = env.now          # Начало выполнения
        delay = beg - put      # Задержка
        yield env.timeout(dur) # Время выполнения
        end = env.now          # Завершение выполнения
        #print(f'{put:2.0f}, {beg:2.0f}, {end:2.0f}, {delay}, {len(res.queue)}, {order}, {oper} - {dur}')
        # Логи выполнения
        data_log.append([put, beg, end, delay, len(res.queue), order, oper])

def order(env, res, order, wait):
    # Ждем запуска
    yield env.timeout(wait)
    # Выполняем операции
    yield env.process(oper(env, res[0], order, '1. Обработка 1', 0, ope[0]))
    yield env.process(oper(env, res[1], order, '2. Обработка 2', 0, ope[1]))
    yield env.process(oper(env, res[2], order, '3. Обработка 3', 0, ope[2]))
    yield env.process(oper(env, res[3], order, '4. Обработка 4', 0, ope[3]))
    yield env.process(oper(env, res[4], order, '5. Обработка 5', 0, ope[4]))

# Иницилизация среды выпполнения имитационной модели
env = simpy.Environment(initial_time=0)

# Создаем ресурс - менеджер
r1 = simpy.PriorityResource(env, random.randint(1, 3))
r2 = simpy.PriorityResource(env, random.randint(1, 3))
r3 = simpy.PriorityResource(env, random.randint(1, 3))
r4 = simpy.PriorityResource(env, random.randint(1, 3))
r5 = simpy.PriorityResource(env, random.randint(1, 3))
res = [r1, r2, r3, r4, r5]
ope = [random.randint(1, 10), random.randint(1, 10), random.randint(1, 10), random.randint(1, 10), random.randint(1, 10)]

n = 9
d = random.randint(5, 10)

# В среду выполнения помещаем три процесса
for i in range(n):

    p1 = env.process(order(env, res, f"Деталь {i+1}", d))

# Лог
data_log = []

# Запускаем моделирование на 500 минут
env.run(until=500)

# Печать лога
#data_log

gant(data_log)
